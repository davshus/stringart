# %%
from artboard import Artboard, Yarn
n=120
board = Artboard(304.8, n)
for i in range(0,n):
    for j in range(0,n):
        board.add_string(i,j)
# board.add_string(0,n//2)

# %%
board.render(background="#FFFFFF").rasterize()
