# %%
# import cv2
import math
import numpy as np
from PIL import Image
import scipy
import scipy.misc
import scipy.sparse
import scipy.sparse.linalg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from artboard import Artboard, Yarn
N_PINS=200
N_STRINGS = 1000
DIAMETER=304.8
DIMENSION = 500
FADE = 25
FILE = 'img/profile.jpg'
board = Artboard(DIAMETER, N_PINS)

#random 500x500 image
img = np.array(Image.open(FILE))
if img.ndim > 2:
    img = img[:, :, 0] #flatten to 1 channel - in prod, will need to loop over all channels
plt.imshow(img, cmap="gray")
plt.colorbar()

# %%
board.generate_stringscape(img, N_STRINGS, 25, 25)
# Out:
#   0%|          | 1/200 [00:00<00:29,  6.73it/s]
# [(550, 0), (533, 0), (515, 1), (498, 2), (481, 4), (464, 6), (447, 9), (430, 13), (413, 17), (397, 21), (380, 26), (364, 32), (348, 38), (332, 45), (316, 52), (300, 59), (285, 68), (270, 76), (255, 85), (241, 95), (227, 105), (213, 115), (199, 126), (186, 137), (173, 149), (161, 161), (149, 173), (137, 186), (126, 199), (115, 212), (105, 226), (95, 240), (86, 255), (77, 270), (68, 285), (60, 300), (52, 315), (45, 331), (39, 347), (33, 363), (27, 380), (22, 396), (17, 413), (13, 430), (10, 446), (7, 463), (4, 481), (2, 498), (1, 515), (0, 532), (0, 549), (0, 567), (1, 584), (2, 601), (4, 618), (7, 636), (10, 653), (13, 669), (17, 686), (22, 703), (27, 719), (33, 736), (39, 752), (45, 768), (52, 784), (60, 799), (68, 814), (77, 829), (86, 844), (95, 859), (105, 873), (115, 887), (126, 900), (137, 913), (149, 926), (161, 938), (173, 950), (186, 962), (199, 973), (213, 984), (227, 994), (241, 1004), (255, 1014), (270, 1023), (285, 1031), (300, 1040), (316, 1047), (332, 1054), (348, 1061), (364, 1067), (380, 1073), (397, 1078), (413, 1082), (430, 1086), (447, 1090), (464, 1093), (481, 1095), (498, 1097), (515, 1098), (533, 1099), (550, 1100), (567, 1099), (585, 1098), (602, 1097), (619, 1095), (636, 1093), (653, 1090), (670, 1086), (687, 1082), (703, 1078), (720, 1073), (736, 1067), (752, 1061), (768, 1054), (784, 1047), (800, 1040), (815, 1031), (830, 1023), (845, 1014), (859, 1004), (873, 994), (887, 984), (901, 973), (914, 962), (927, 950), (939, 938), (951, 926), (963, 913), (974, 900), (985, 887), (995, 873), (1005, 859), (1014, 844), (1023, 829), (1032, 814), (1040, 799), (1048, 784), (1055, 768), (1061, 752), (1067, 736), (1073, 719), (1078, 703), (1083, 686), (1087, 669), (1090, 653), (1093, 636), (1096, 618), (1098, 601), (1099, 584), (1099, 567), (1099, 550), (1099, 532), (1099, 515), (1098, 498), (1096, 481), (1093, 463), (1090, 446), (1087, 430), (1083, 413), (1078, 396), (1073, 380), (1067, 363), (1061, 347), (1055, 331), (1048, 315), (1040, 300), (1032, 285), (1023, 270), (1014, 255), (1005, 240), (995, 226), (985, 212), (974, 199), (963, 186), (951, 173), (939, 161), (927, 149), (914, 137), (901, 126), (887, 115), (873, 105), (859, 95), (845, 85), (830, 76), (815, 68), (800, 59), (784, 52), (768, 45), (752, 38), (736, 32), (720, 26), (703, 21), (687, 17), (670, 13), (653, 9), (636, 6), (619, 4), (602, 2), (585, 1), (567, 0)]
# 100%|██████████| 200/200 [00:22<00:00,  8.79it/s]
#  28%|██▊       | 276/1000 [02:17<06:12,  1.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-54be238fcbf7> in <module>
# ----> 1 board.generate_stringscape(img, N_STRINGS, 25, 25)
#
# ~/developer/stringart/artboard.py in generate_stringscape(self, img, n_strings, fade, min_distance, scoring_method)
#     209
#     210         for i in tqdm(range(0, n_strings)):
# --> 211             next = self.scape_next_pin(current, img, min_distance, scoring_method)
#     212             self.add_string(next, current)
#     213             #print (f"{i}/{n_strings}: {current} -> {next}")
#
# ~/developer/stringart/artboard.py in scape_next_pin(self, current, img, min_distance, score_func)
#     129                 continue
#     130
# --> 131             score = score_func(img, self.line_pixels[pair])
#     132             if score > max_score:
#     133                 max_score = score
#
# ~/developer/stringart/artboard.py in naive(img, points)
#      38         score = 0
#      39         for p in points:
# ---> 40             c = img[p.y][p.x] & 0xff
#      41             score += 0xff - c
#      42         return score / len(points)
#
# KeyboardInterrupt:

# %%
board.render(background="white").rasterize()

# %%
plt.imshow(img, cmap="gray")
