# %%
# import cv2
import math
import numpy as np
from PIL import Image
import scipy
import scipy.misc
import scipy.sparse
import scipy.sparse.linalg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from artboard import Artboard, Yarn
N_PINS=200
N_STRINGS = 1000
DIAMETER=304.8
DIMENSION = 500
FADE = 25
FILE = 'img/wolf.jpg'
board = Artboard(DIAMETER, N_PINS)

#random 500x500 image
img = np.array(Image.open(FILE))
if img.ndim > 2:
    img = img[:, :, 0] #flatten to 1 channel - in prod, will need to loop over all channels
plt.imshow(img, cmap="gray")
plt.colorbar()

# %%
board.generate_stringscape(img, N_STRINGS, 25, 25)
# Out:
# [(250, 0), (242, 0), (234, 0), (226, 0), (219, 1), (211, 2), (203, 3), (195, 5), (188, 7), (180, 9), (173, 11), (165, 14), (158, 17), (151, 20), (144, 23), (137, 26), (130, 30), (123, 34), (116, 38), (109, 42), (103, 47), (97, 51), (91, 56), (85, 61), (79, 67), (73, 72), (68, 78), (62, 84), (57, 90), (52, 96), (48, 102), (43, 108), (39, 115), (35, 122), (31, 129), (27, 136), (24, 143), (21, 150), (18, 157), (15, 164), (12, 172), (10, 179), (8, 187), (6, 194), (4, 202), (3, 210), (2, 218), (1, 225), (0, 233), (0, 241), (0, 249), (0, 257), (0, 265), (1, 273), (2, 280), (3, 288), (4, 296), (6, 304), (8, 311), (10, 319), (12, 326), (15, 334), (18, 341), (21, 348), (24, 355), (27, 362), (31, 369), (35, 376), (39, 383), (43, 390), (48, 396), (52, 402), (57, 408), (62, 414), (68, 420), (73, 426), (79, 431), (85, 437), (91, 442), (97, 447), (103, 451), (109, 456), (116, 460), (123, 464), (130, 468), (137, 472), (144, 475), (151, 478), (158, 481), (165, 484), (173, 487), (180, 489), (188, 491), (195, 493), (203, 495), (211, 496), (219, 497), (226, 498), (234, 499), (242, 499), (250, 499), (258, 499), (266, 499), (274, 498), (281, 497), (289, 496), (297, 495), (305, 493), (312, 491), (320, 489), (327, 487), (335, 484), (342, 481), (349, 478), (356, 475), (363, 472), (370, 468), (377, 464), (384, 460), (391, 456), (397, 451), (403, 447), (409, 442), (415, 437), (421, 431), (427, 426), (432, 420), (438, 414), (443, 408), (448, 402), (452, 396), (457, 390), (461, 383), (465, 376), (469, 369), (473, 362), (476, 355), (479, 348), (482, 341), (485, 334), (488, 326), (490, 319), (492, 311), (494, 304), (496, 296), (497, 288), (498, 280), (499, 273), (499, 265), (499, 257), (499, 249), (499, 241), (499, 233), (499, 225), (498, 218), (497, 210), (496, 202), (494, 194), (492, 187), (490, 179), (488, 172), (485, 164), (482, 157), (479, 150), (476, 143), (473, 136), (469, 129), (465, 122), (461, 115), (457, 108), (452, 102), (448, 96), (443, 90), (438, 84), (432, 78), (427, 72), (421, 67), (415, 61), (409, 56), (403, 51), (397, 47), (391, 42), (384, 38), (377, 34), (370, 30), (363, 26), (356, 23), (349, 20), (342, 17), (335, 14), (327, 11), (320, 9), (312, 7), (305, 5), (297, 3), (289, 2), (281, 1), (274, 0), (266, 0), (258, 0)]

# %%
board.render(background="white").rasterize()

# %%
plt.imshow(img, cmap="gray")
